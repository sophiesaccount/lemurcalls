# %% [markdown]
# ## Experiments
#
# Goals:
# - get baseline results for Bens Model and AF
# - evaluate if I want to further use the given labels
# - see how the performance changes when applying amplitude thresholds
